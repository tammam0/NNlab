# %%
import tensorflow as tf
import numpy as np

# %%
N, D, H = 64, 1000, 100
model=tf.keras.Sequential()
model.add(tf.keras.layers.Dense(H,input_shape=(D,), activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(D))
model.compile(loss=tf.keras.losses.mean_squared_error, optimizer=tf.keras.optimizers.Adagrad(lr=1e0))   #Using Adagrad method

# %%
x=np.random.randn(N,D)
y=np.random.randn(N,D)
history=model.fit(x,y,epochs=50,batch_size=N)
# Out:
# Epoch 1/50
# 64/64 [==============================] - 0s 125us/step - loss: 827778.0000
# Epoch 2/50
# 64/64 [==============================] - 0s 156us/step - loss: 14309.5996
# Epoch 3/50
# 64/64 [==============================] - 0s 141us/step - loss: 488.4220
# Epoch 4/50
# 64/64 [==============================] - 0s 125us/step - loss: 191.0871
# Epoch 5/50
# 64/64 [==============================] - 0s 219us/step - loss: 101.0062
# Epoch 6/50
# 64/64 [==============================] - 0s 219us/step - loss: 58.0207
# Epoch 7/50
# 64/64 [==============================] - 0s 125us/step - loss: 35.3058
# Epoch 8/50
# 64/64 [==============================] - 0s 203us/step - loss: 22.2912
# Epoch 9/50
# 64/64 [==============================] - 0s 187us/step - loss: 14.5545
# Epoch 10/50
# 64/64 [==============================] - 0s 141us/step - loss: 9.8095
# Epoch 11/50
# 64/64 [==============================] - 0s 141us/step - loss: 6.8297
# Epoch 12/50
# ...
