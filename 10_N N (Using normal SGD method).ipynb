# %%
import tensorflow as tf
import numpy as np

# %%
N, D, H = 64, 1000, 100
model=tf.keras.Sequential()
model.add(tf.keras.layers.Dense(H,input_shape=(D,), activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(D))
model.compile(loss=tf.keras.losses.mean_squared_error, optimizer=tf.keras.optimizers.SGD(lr=1e0))   #Using normal SGD method

# %%
x=np.random.randn(N,D)
y=np.random.randn(N,D)
history=model.fit(x,y,epochs=50,batch_size=N)
# Out:
# Epoch 1/50
# 64/64 [==============================] - 0s 141us/step - loss: 1.1165
# Epoch 2/50
# 64/64 [==============================] - 0s 141us/step - loss: 1.0904
# Epoch 3/50
# 64/64 [==============================] - 0s 172us/step - loss: 1.0687
# Epoch 4/50
# 64/64 [==============================] - 0s 156us/step - loss: 1.0505
# Epoch 5/50
# 64/64 [==============================] - 0s 125us/step - loss: 1.0351
# Epoch 6/50
# 64/64 [==============================] - 0s 172us/step - loss: 1.0219
# Epoch 7/50
# 64/64 [==============================] - 0s 219us/step - loss: 1.0105
# Epoch 8/50
# 64/64 [==============================] - 0s 156us/step - loss: 1.0006
# Epoch 9/50
# 64/64 [==============================] - 0s 141us/step - loss: 0.9918
# Epoch 10/50
# 64/64 [==============================] - 0s 141us/step - loss: 0.9842
# Epoch 11/50
# 64/64 [==============================] - 0s 125us/step - loss: 0.9773
# Epoch 12/50
# ...
